# %%
#1:
s1 = input("Nhap chuoi 1: ")
print(len(s1))
#2:
s2 = input("Nhap chuoi 2: ")
print(s2.upper())
#3:
s3 = input("Nhap chuoi 3: ")
print(s3.lower())
#4:
s4 = input("Nhap chuoi 4: ")
kt = input("Nhap ki tu: ")
count = 0
for i in range(len(s4)):
    if(s4[i] == kt):
        count += 1
print(count)
#5:
s5 = input("Nhap chuoi 5: ")
if(len(s5)) == 0:
    print("Chuoi rong")
#6:
s6 = input("Nhap chuoi 6: ")
print(s6[::-1])
#7:
s7 = input("Nhap chuoi 7: ")
s = input("Nhap chuoi con: ")
print(s7.startswith(s))
#8:
s8 = input("Nhap chuoi 8: ")
s = input("Nhap chuoi con: ")
print(s8.endswith(s))
#9:
s9 = input("Nhap chuoi 9: ")
print(s9.replace("like","love"))
#10:
s10 = input("Nhap chuoi 10: ")
a= s10.split(" ");
print(a)
#11:
list = ["Hello", "World"]
s = list[0] + " " + list[1]
print(s)
#12:
s12 = input("Nhap chuoi 12: ")
check = False
for i in range(len(s12)):
    if s12[i].isdigit():
        check = True
        break
print(check)
#13:
s13 = input("Nhap chuoi 13: ")
check = True
for i in range(len(s13)):
    if s13[i].isdigit():
        check = False
        break
print(check)
#14:
s14 = input("Nhap chuoi 14: ")
check = True
for i in range(len(s14)):
    if s14[i].isalpha():
        check = False
        break
print(check)
#15:
s15 = input("Nhap chuoi 15: ")
start = int(input("Chi so dau: "))
end = int(input("Chi so cuoi: "))
print(s15[start:end])
#16:
s16 = input("Nhap chuoi 16: ")
s = s16.split(" ")
print(len(s))
#17:
s17 = input("Nhap chuoi 17: ")
print(s17.strip(" "))
#18:
s18 = input("Nhap chuoi 18: ")
print(s18[1:len(s18)-1])
